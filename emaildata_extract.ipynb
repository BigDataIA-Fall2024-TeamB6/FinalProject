# %% [markdown]
# # Fetching email content and PDF Handling
# The code integrates with the Microsoft Graph API to interact with email data, fetching email content and attachments. It processes the retrieved emails to extract relevant attachments and transforms the data for further use. For attachments in PDF format, the code employs fitz (PyMuPDF) to handle operations such as extracting text, images, and tables.

# %%
import os
import json
import base64
import requests
from msal import ConfidentialClientApplication
from datetime import datetime
from PIL import Image
from io import BytesIO
import fitz 
from unidecode import unidecode

# %%
# Define constants
CLIENT_ID = os.getenv("CLIENT_ID")
TENANT_ID = os.getenv("TENANT_ID")
CLIENT_SECRET = os.getenv("CLIENT_SECRET")
EMAIL = os.getenv("EMAIL")

# %%
# Ensure downloads folder exists
downloads_folder = "downloads"
os.makedirs(downloads_folder, exist_ok=True)

# %%
def sanitize_filename(filename):
    """Sanitize filenames to avoid illegal characters."""
    return "".join(c for c in filename if c.isalnum() or c in (' ', '_')).rstrip()

# %%
def get_access_token():
    """Fetch an access token from Azure."""
    app = ConfidentialClientApplication(
        CLIENT_ID,
        authority=f"https://login.microsoftonline.com/{TENANT_ID}",
        client_credential=CLIENT_SECRET,
    )
    token_response = app.acquire_token_for_client(scopes=["https://graph.microsoft.com/.default"])
    if "access_token" in token_response:
        return token_response["access_token"]
    else:
        raise Exception("Access token acquisition failed.")

# %%
def fetch_emails():
    """Fetch emails using Microsoft Graph API."""
    token = get_access_token()
    headers = {"Authorization": f"Bearer {token}"}
    endpoint = f"https://graph.microsoft.com/v1.0/users/{EMAIL}/messages"
    params = {
        "$select": "subject,sender,receivedDateTime,bodyPreview",
        "$top": 10,
        "$expand": "attachments"
    }
    response = requests.get(endpoint, headers=headers, params=params)
    response.raise_for_status()
    emails = response.json()

    for email in emails.get("value", []):
        save_email(email)

# %%
def save_email(email_data):
    """Save email content, attachments, and generate TTS."""
    subject = email_data.get('subject', 'No Subject')
    email_folder_path = os.path.join(downloads_folder, subject)
    document_id = subject
    counter = 1
    while os.path.exists(os.path.join(downloads_folder, f"{subject}_{counter}")):
        counter += 1

    document_id = f"{subject}_{counter}"
    email_folder_path = os.path.join(downloads_folder, document_id)



    # Check if the folder already exists
    if os.path.exists(email_folder_path):
        print(f"Email with document ID {document_id} already processed. Skipping.")
        return

    os.makedirs(email_folder_path, exist_ok=True)

    # Use bodyPreview instead of full body
    email_metadata = {
        "document_id": document_id,  
        "subject": email_data.get('subject', 'No Subject'),
        "sender": email_data["sender"]["emailAddress"]["address"],
        "received_time": email_data["receivedDateTime"],
        "body_preview": email_data.get("bodyPreview", "No preview available")  # Extracting bodyPreview
    }

    metadata_path = os.path.join(email_folder_path, "metadata.json")
    with open(metadata_path, 'w') as metadata_file:
        json.dump(email_metadata, metadata_file, indent=4)

    # Generate Text-to-Speech using bodyPreview
    combined_text = (
        f"Subject: {email_metadata['subject']}. "
        f"Content: {email_metadata['body_preview']}. "  # Use bodyPreview
        f"Sender: {email_metadata['sender']}. "
        f"Received Time: {email_metadata['received_time']}."
    )

    # Save attachments
    for attachment in email_data.get("attachments", []):
        attachment_name = attachment.get('name', 'Unnamed_Attachment')
        attachment_data = attachment.get('contentBytes')
        if not attachment_data:
            continue

        content = base64.b64decode(attachment_data)
        if attachment_name.lower().endswith('.pdf'):
            save_pdf_attachment(content, email_folder_path, attachment_name)
        elif any(attachment_name.lower().endswith(ext) for ext in ['jpg', 'jpeg', 'png', 'gif']):
            save_image_attachment(content, email_folder_path, attachment_name)

# %%
def save_pdf_attachment(content, folder_path, filename):
    """Save PDF attachments as .pdf files."""
    try:
        base_name = sanitize_filename(os.path.splitext(filename)[0])
        sanitized_filename = f"{base_name}.pdf"
        pdf_path = os.path.join(folder_path, sanitized_filename)
        with open(pdf_path, 'wb') as pdf_file:
            pdf_file.write(content)
        print(f"Saved PDF: {pdf_path}")
    except Exception as e:
        print(f"Failed to save PDF {filename}: {e}")

# %%
def save_image_attachment(content, folder_path, filename):
    """Save image attachments in their original format without conversion."""
    try:
        image = Image.open(BytesIO(content))
        original_format = image.format.lower()
        valid_formats = ['jpg', 'jpeg', 'png', 'gif', 'bmp', 'tiff']
        if original_format not in valid_formats:
            print(f"Unsupported image format {original_format}. Saving as PNG.")
            original_format = "png"
        sanitized_filename = sanitize_filename(os.path.splitext(filename)[0])
        image_filename = f"{sanitized_filename}.{original_format}"
        image_path = os.path.join(folder_path, image_filename)
        image.save(image_path, format=image.format.upper())
        print(f"Saved image: {image_path}")
    except Exception as e:
        print(f"Failed to save image {filename}: {e}")

# %%
def process_pdfs_in_downloads():
    """Process all PDFs in the downloads folder and extract content."""
    print("Starting to process PDFs in downloads folder...")
    for root, dirs, files in os.walk(downloads_folder):
        print(f"Checking directory: {root}")
        for file in files:
            if file.lower().endswith('.pdf'):
                pdf_path = os.path.join(root, file)
                base_dir = os.path.splitext(pdf_path)[0]
                print(f"Found PDF: {pdf_path}")
                extract_content_from_pdf(pdf_path, base_dir)

# %%
def extract_content_from_pdf(pdf_path, base_dir):
    """Extract content from a PDF and save text, images, and tables."""
    print(f"Opening PDF: {pdf_path}")
    try:
        document = fitz.open(pdf_path)
        json_dir = os.path.join(base_dir, 'JSON')
        img_dir = os.path.join(base_dir, 'Image')
        csv_dir = os.path.join(base_dir, 'CSV')

        print(f"Creating directories for extracted content:")
        print(f"  JSON directory: {json_dir}")
        print(f"  Image directory: {img_dir}")
        print(f"  CSV directory: {csv_dir}")
        
        os.makedirs(json_dir, exist_ok=True)
        os.makedirs(img_dir, exist_ok=True)
        os.makedirs(csv_dir, exist_ok=True)

        for page_num in range(document.page_count):
            print(f"Processing page {page_num + 1} of {pdf_path}")
            try:
                page = document[page_num]
                page_id = page_num + 1
                page_content = {
                    "page_id": page_id,
                    "content": {}
                }

                # Extract text
                text = page.get_text("text")
                print(f"Extracted text for page {page_id}: {text[:100]}...")  # Print first 100 chars
                page_content['content']['text'] = unidecode(text)

                # Extract images
                image_list = []
                images = page.get_images(full=True)
                print(f"Found {len(images)} images on page {page_id}")
                for img_index, img in enumerate(images):
                    try:
                        xref = img[0]
                        img_data = document.extract_image(xref)
                        img_ext = img_data["ext"]
                        img_name = f"{page_id}_image_{img_index}.{img_ext}"
                        img_path = os.path.join(img_dir, img_name)
                        with open(img_path, 'wb') as img_file:
                            img_file.write(img_data["image"])
                        print(f"  Extracted image: {img_name}")
                        image_list.append(img_name)
                    except Exception as exception:
                        print(f"Error extracting image on Page {page_id} of PDF {pdf_path}: {exception}")
                page_content['content']['image'] = image_list

                # Extract tables (dummy for now)
                table_list = []
                print(f"No table extraction implemented yet for page {page_id}")
                page_content['content']['table'] = table_list

                # Save JSON
                json_file_path = os.path.join(json_dir, f"{page_id}.json")
                with open(json_file_path, 'w') as json_file:
                    json.dump(page_content, json_file, indent=4)
                print(f"Saved JSON for page {page_id}: {json_file_path}")
            except Exception as exception:
                print(f"Error processing Page {page_num + 1} of PDF {pdf_path}: {exception}")
    except Exception as exception:
        print(f"Failed to open the PDF document {pdf_path}: {exception}")

# %%
if __name__ == "__main__":
    fetch_emails()
    process_pdfs_in_downloads()
# Out:
# Saved PDF: downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Saved image: downloads/test (with pdf)_1/docling.jpeg
# Saved PDF: downloads/Mail with image_1/Final Project Proposaledited.pdf
# Saved image: downloads/Mail with image_1/docling.jpeg
# Saved PDF: downloads/Manual mail_1/Final Project Proposaledited.pdf
# Starting to process PDFs in downloads folder...
# Checking directory: downloads
# Checking directory: downloads/Manual mail_1
# Found PDF: downloads/Manual mail_1/Final Project Proposaledited.pdf
# Opening PDF: downloads/Manual mail_1/Final Project Proposaledited.pdf
# Creating directories for extracted content:
#   JSON directory: downloads/Manual mail_1/Final Project Proposaledited/JSON
#   Image directory: downloads/Manual mail_1/Final Project Proposaledited/Image
#   CSV directory: downloads/Manual mail_1/Final Project Proposaledited/CSV
# Processing page 1 of downloads/Manual mail_1/Final Project Proposaledited.pdf
# Extracted text for page 1: Final Project Proposal
# Due: 22nd Nov 24 03:59 pm EST
# Submission:
#
# 1. Github Repo Link
# Additiona...
# Found 0 images on page 1
# No table extraction implemented yet for page 1
# Saved JSON for page 1: downloads/Manual mail_1/Final Project Proposaledited/JSON/1.json
# Processing page 2 of downloads/Manual mail_1/Final Project Proposaledited.pdf
# Extracted text for page 2: Data Sources: Identify and describe the sources of data to be collected, processed, and analyzed. or...
# Found 0 images on page 2
# No table extraction implemented yet for page 2
# Saved JSON for page 2: downloads/Manual mail_1/Final Project Proposaledited/JSON/2.json
# Processing page 3 of downloads/Manual mail_1/Final Project Proposaledited.pdf
# Extracted text for page 3: Deploy the application on a cloud platform such as AWS, Google Cloud, or Azure, making it publicly a...
# Found 0 images on page 3
# No table extraction implemented yet for page 3
# Saved JSON for page 3: downloads/Manual mail_1/Final Project Proposaledited/JSON/3.json
# Checking directory: downloads/test (with pdf)_1
# Found PDF: downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Opening PDF: downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Creating directories for extracted content:
#   JSON directory: downloads/test (with pdf)_1/risk_compilation_2018/JSON
#   Image directory: downloads/test (with pdf)_1/risk_compilation_2018/Image
#   CSV directory: downloads/test (with pdf)_1/risk_compilation_2018/CSV
# Processing page 1 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 1: Edited by Joachim Klement, CFA
# RISK PROFILING AND TOLERANCE:
# INSIGHTS FOR THE PRIVATE
# WEALTH MANAG...
# Found 1 images on page 1
#   Extracted image: 1_image_0.jpeg
# No table extraction implemented yet for page 1
# Saved JSON for page 1: downloads/test (with pdf)_1/risk_compilation_2018/JSON/1.json
# Processing page 2 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 2: RISK PROFILING AND TOLERANCE:
# INSIGHTS FOR THE PRIVATE
# WEALTH MANAGER
# Edited by Joachim Klement, C...
# Found 0 images on page 2
# No table extraction implemented yet for page 2
# Saved JSON for page 2: downloads/test (with pdf)_1/risk_compilation_2018/JSON/2.json
# Processing page 3 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 3: Statement of Purpose
# CFA Institute Research Foundation is a not-for-
# profit organization established...
# Found 0 images on page 3
# No table extraction implemented yet for page 3
# Saved JSON for page 3: downloads/test (with pdf)_1/risk_compilation_2018/JSON/3.json
# Processing page 4 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 4: CONTENTS
# Biographies...................................................................................
# Found 0 images on page 4
# No table extraction implemented yet for page 4
# Saved JSON for page 4: downloads/test (with pdf)_1/risk_compilation_2018/JSON/4.json
# Processing page 5 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 5: ...
# Found 0 images on page 5
# No table extraction implemented yet for page 5
# Saved JSON for page 5: downloads/test (with pdf)_1/risk_compilation_2018/JSON/5.json
# Processing page 6 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 6:  CFA Institute Research Foundation  |  v
# BIOGRAPHIES
# Joachim Klement, CFA, is the head of investmen...
# Found 0 images on page 6
# No table extraction implemented yet for page 6
# Saved JSON for page 6: downloads/test (with pdf)_1/risk_compilation_2018/JSON/6.json
# Processing page 7 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 7: Biographies
# vi  |  CFA Institute Research Foundation
# Elke U. Weber is the Gerhard R. Andlinger Profe...
# Found 0 images on page 7
# No table extraction implemented yet for page 7
# Saved JSON for page 7: downloads/test (with pdf)_1/risk_compilation_2018/JSON/7.json
# Processing page 8 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 8:  CFA Institute Research Foundation  |  vii
# FOREWORD
# Bob Dannhauser, CFA
# Head, Private Wealth Manage...
# Found 0 images on page 8
# No table extraction implemented yet for page 8
# Saved JSON for page 8: downloads/test (with pdf)_1/risk_compilation_2018/JSON/8.json
# Processing page 9 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 9: ...
# Found 0 images on page 9
# No table extraction implemented yet for page 9
# Saved JSON for page 9: downloads/test (with pdf)_1/risk_compilation_2018/JSON/9.json
# Processing page 10 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 10:  CFA Institute Research Foundation  |  ix
# PREFACE
# Investing Is Rational, Money Is Emotional
# Ever si...
# Found 1 images on page 10
#   Extracted image: 10_image_0.jpeg
# No table extraction implemented yet for page 10
# Saved JSON for page 10: downloads/test (with pdf)_1/risk_compilation_2018/JSON/10.json
# Processing page 11 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 11: Preface
# x  |  CFA Institute Research Foundation
# At the end of this preface, you will find a zoomed-o...
# Found 0 images on page 11
# No table extraction implemented yet for page 11
# Saved JSON for page 11: downloads/test (with pdf)_1/risk_compilation_2018/JSON/11.json
# Processing page 12 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 12: Preface
#  CFA Institute Research Foundation  |  xi
# In the second part of the series, behavioral fina...
# Found 0 images on page 12
# No table extraction implemented yet for page 12
# Saved JSON for page 12: downloads/test (with pdf)_1/risk_compilation_2018/JSON/12.json
# Processing page 13 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 13: Preface
# xii  |  CFA Institute Research Foundation
# Though extensive, the list of topics covered in th...
# Found 1 images on page 13
#   Extracted image: 13_image_0.jpeg
# No table extraction implemented yet for page 13
# Saved JSON for page 13: downloads/test (with pdf)_1/risk_compilation_2018/JSON/13.json
# Processing page 14 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 14:  CFA Institute Research Foundation  |  1
# INVESTOR RISK PROFILING:
# AN OVERVIEW
# Joachim Klement, CFA...
# Found 0 images on page 14
# No table extraction implemented yet for page 14
# Saved JSON for page 14: downloads/test (with pdf)_1/risk_compilation_2018/JSON/14.json
# Processing page 15 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 15: Investor Risk Profiling
# 2  |  CFA Institute Research Foundation
# provides guidance on suitability; in...
# Found 0 images on page 15
# No table extraction implemented yet for page 15
# Saved JSON for page 15: downloads/test (with pdf)_1/risk_compilation_2018/JSON/15.json
# Processing page 16 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 16: Investor Risk Profiling
#  CFA Institute Research Foundation  |  3
# Risk capacity applies to the objec...
# Found 0 images on page 16
# No table extraction implemented yet for page 16
# Saved JSON for page 16: downloads/test (with pdf)_1/risk_compilation_2018/JSON/16.json
# Processing page 17 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 17: Investor Risk Profiling
# 4  |  CFA Institute Research Foundation
# type of product, that person’s finan...
# Found 0 images on page 17
# No table extraction implemented yet for page 17
# Saved JSON for page 17: downloads/test (with pdf)_1/risk_compilation_2018/JSON/17.json
# Processing page 18 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 18: Investor Risk Profiling
#  CFA Institute Research Foundation  |  5
# If we assume for the moment that t...
# Found 0 images on page 18
# No table extraction implemented yet for page 18
# Saved JSON for page 18: downloads/test (with pdf)_1/risk_compilation_2018/JSON/18.json
# Processing page 19 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 19: Investor Risk Profiling
# 6  |  CFA Institute Research Foundation
# The influence of framing on the outc...
# Found 0 images on page 19
# No table extraction implemented yet for page 19
# Saved JSON for page 19: downloads/test (with pdf)_1/risk_compilation_2018/JSON/19.json
# Processing page 20 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 20: Investor Risk Profiling
#  CFA Institute Research Foundation  |  7
# third higher than in the percentag...
# Found 0 images on page 20
# No table extraction implemented yet for page 20
# Saved JSON for page 20: downloads/test (with pdf)_1/risk_compilation_2018/JSON/20.json
# Processing page 21 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 21: Investor Risk Profiling
# 8  |  CFA Institute Research Foundation
# seems to be typically done in such a...
# Found 0 images on page 21
# No table extraction implemented yet for page 21
# Saved JSON for page 21: downloads/test (with pdf)_1/risk_compilation_2018/JSON/21.json
# Processing page 22 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 22: Investor Risk Profiling
#  CFA Institute Research Foundation  |  9
# RECENT FINDINGS ABOUT TRUE
# INFLUE...
# Found 0 images on page 22
# No table extraction implemented yet for page 22
# Saved JSON for page 22: downloads/test (with pdf)_1/risk_compilation_2018/JSON/22.json
# Processing page 23 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 23: Investor Risk Profiling
# 10  |  CFA Institute Research Foundation
# Similar results were found by an in...
# Found 0 images on page 23
# No table extraction implemented yet for page 23
# Saved JSON for page 23: downloads/test (with pdf)_1/risk_compilation_2018/JSON/23.json
# Processing page 24 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 24: Investor Risk Profiling
#  CFA Institute Research Foundation  |  11
# behavior from those who did not—e...
# Found 0 images on page 24
# No table extraction implemented yet for page 24
# Saved JSON for page 24: downloads/test (with pdf)_1/risk_compilation_2018/JSON/24.json
# Processing page 25 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 25: Investor Risk Profiling
# 12  |  CFA Institute Research Foundation
# averse throughout a stressful finan...
# Found 0 images on page 25
# No table extraction implemented yet for page 25
# Saved JSON for page 25: downloads/test (with pdf)_1/risk_compilation_2018/JSON/25.json
# Processing page 26 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 26: Investor Risk Profiling
#  CFA Institute Research Foundation  |  13
# should investigate the past inves...
# Found 0 images on page 26
# No table extraction implemented yet for page 26
# Saved JSON for page 26: downloads/test (with pdf)_1/risk_compilation_2018/JSON/26.json
# Processing page 27 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 27: Investor Risk Profiling
# 14  |  CFA Institute Research Foundation
# aware of this problem and are requi...
# Found 0 images on page 27
# No table extraction implemented yet for page 27
# Saved JSON for page 27: downloads/test (with pdf)_1/risk_compilation_2018/JSON/27.json
# Processing page 28 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 28: Investor Risk Profiling
#  CFA Institute Research Foundation  |  15
# REFERENCES
# Barnea, A., H. Cronqvi...
# Found 0 images on page 28
# No table extraction implemented yet for page 28
# Saved JSON for page 28: downloads/test (with pdf)_1/risk_compilation_2018/JSON/28.json
# Processing page 29 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 29: Investor Risk Profiling
# 16  |  CFA Institute Research Foundation
# Heaton, J., and D. Lucas. 2000. “Po...
# Found 0 images on page 29
# No table extraction implemented yet for page 29
# Saved JSON for page 29: downloads/test (with pdf)_1/risk_compilation_2018/JSON/29.json
# Processing page 30 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 30:  CFA Institute Research Foundation  |  17
# RISK PROFILING THROUGH A
# BEHAVIORAL FINANCE LENS
# Michael...
# Found 0 images on page 30
# No table extraction implemented yet for page 30
# Saved JSON for page 30: downloads/test (with pdf)_1/risk_compilation_2018/JSON/30.json
# Processing page 31 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 31: Risk Profiling through a Behavioral Finance Lens
# 18  |  CFA Institute Research Foundation
# seven year...
# Found 0 images on page 31
# No table extraction implemented yet for page 31
# Saved JSON for page 31: downloads/test (with pdf)_1/risk_compilation_2018/JSON/31.json
# Processing page 32 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 32: Risk Profiling through a Behavioral Finance Lens
#  CFA Institute Research Foundation  |  19
# overview...
# Found 0 images on page 32
# No table extraction implemented yet for page 32
# Saved JSON for page 32: downloads/test (with pdf)_1/risk_compilation_2018/JSON/32.json
# Processing page 33 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 33: Risk Profiling through a Behavioral Finance Lens
# 20  |  CFA Institute Research Foundation
# biases and...
# Found 0 images on page 33
# No table extraction implemented yet for page 33
# Saved JSON for page 33: downloads/test (with pdf)_1/risk_compilation_2018/JSON/33.json
# Processing page 34 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 34: Risk Profiling through a Behavioral Finance Lens
#  CFA Institute Research Foundation  |  21
# expect o...
# Found 0 images on page 34
# No table extraction implemented yet for page 34
# Saved JSON for page 34: downloads/test (with pdf)_1/risk_compilation_2018/JSON/34.json
# Processing page 35 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 35: Risk Profiling through a Behavioral Finance Lens
# 22  |  CFA Institute Research Foundation
# unknown ri...
# Found 0 images on page 35
# No table extraction implemented yet for page 35
# Saved JSON for page 35: downloads/test (with pdf)_1/risk_compilation_2018/JSON/35.json
# Processing page 36 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 36: Risk Profiling through a Behavioral Finance Lens
#  CFA Institute Research Foundation  |  23
# Although...
# Found 0 images on page 36
# No table extraction implemented yet for page 36
# Saved JSON for page 36: downloads/test (with pdf)_1/risk_compilation_2018/JSON/36.json
# Processing page 37 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 37: Risk Profiling through a Behavioral Finance Lens
# 24  |  CFA Institute Research Foundation
# from educa...
# Found 0 images on page 37
# No table extraction implemented yet for page 37
# Saved JSON for page 37: downloads/test (with pdf)_1/risk_compilation_2018/JSON/37.json
# Processing page 38 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 38: Risk Profiling through a Behavioral Finance Lens
#  CFA Institute Research Foundation  |  25
# CONSERVA...
# Found 0 images on page 38
# No table extraction implemented yet for page 38
# Saved JSON for page 38: downloads/test (with pdf)_1/risk_compilation_2018/JSON/38.json
# Processing page 39 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 39: Risk Profiling through a Behavioral Finance Lens
# 26  |  CFA Institute Research Foundation
# Endowment ...
# Found 0 images on page 39
# No table extraction implemented yet for page 39
# Saved JSON for page 39: downloads/test (with pdf)_1/risk_compilation_2018/JSON/39.json
# Processing page 40 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 40: Risk Profiling through a Behavioral Finance Lens
#  CFA Institute Research Foundation  |  27
# MODERATE...
# Found 0 images on page 40
# No table extraction implemented yet for page 40
# Saved JSON for page 40: downloads/test (with pdf)_1/risk_compilation_2018/JSON/40.json
# Processing page 41 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 41: Risk Profiling through a Behavioral Finance Lens
# 28  |  CFA Institute Research Foundation
# Hindsight ...
# Found 0 images on page 41
# No table extraction implemented yet for page 41
# Saved JSON for page 41: downloads/test (with pdf)_1/risk_compilation_2018/JSON/41.json
# Processing page 42 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 42: Risk Profiling through a Behavioral Finance Lens
#  CFA Institute Research Foundation  |  29
# moderate...
# Found 0 images on page 42
# No table extraction implemented yet for page 42
# Saved JSON for page 42: downloads/test (with pdf)_1/risk_compilation_2018/JSON/42.json
# Processing page 43 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 43: Risk Profiling through a Behavioral Finance Lens
# 30  |  CFA Institute Research Foundation
# The behavi...
# Found 0 images on page 43
# No table extraction implemented yet for page 43
# Saved JSON for page 43: downloads/test (with pdf)_1/risk_compilation_2018/JSON/43.json
# Processing page 44 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 44: Risk Profiling through a Behavioral Finance Lens
#  CFA Institute Research Foundation  |  31
# Self-Att...
# Found 0 images on page 44
# No table extraction implemented yet for page 44
# Saved JSON for page 44: downloads/test (with pdf)_1/risk_compilation_2018/JSON/44.json
# Processing page 45 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 45: Risk Profiling through a Behavioral Finance Lens
# 32  |  CFA Institute Research Foundation
# AGGRESSIVE...
# Found 0 images on page 45
# No table extraction implemented yet for page 45
# Saved JSON for page 45: downloads/test (with pdf)_1/risk_compilation_2018/JSON/45.json
# Processing page 46 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 46: Risk Profiling through a Behavioral Finance Lens
#  CFA Institute Research Foundation  |  33
# Self-Con...
# Found 0 images on page 46
# No table extraction implemented yet for page 46
# Saved JSON for page 46: downloads/test (with pdf)_1/risk_compilation_2018/JSON/46.json
# Processing page 47 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 47: Risk Profiling through a Behavioral Finance Lens
# 34  |  CFA Institute Research Foundation
# Advice for...
# Found 0 images on page 47
# No table extraction implemented yet for page 47
# Saved JSON for page 47: downloads/test (with pdf)_1/risk_compilation_2018/JSON/47.json
# Processing page 48 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 48:  CFA Institute Research Foundation  |  35
# FINANCIAL RISK TOLERANCE:
# A PSYCHOMETRIC REVIEW
# John E. ...
# Found 0 images on page 48
# No table extraction implemented yet for page 48
# Saved JSON for page 48: downloads/test (with pdf)_1/risk_compilation_2018/JSON/48.json
# Processing page 49 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 49: Financial Risk Tolerance
# 36 | CFA Institute Research Foundation
# As behavioral economics and behavior...
# Found 0 images on page 49
# No table extraction implemented yet for page 49
# Saved JSON for page 49: downloads/test (with pdf)_1/risk_compilation_2018/JSON/49.json
# Processing page 50 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 50: Financial Risk Tolerance
#  CFA Institute Research Foundation  |  37
# EXHIBIT 1.  RISK TERMS AND DEFIN...
# Found 0 images on page 50
# No table extraction implemented yet for page 50
# Saved JSON for page 50: downloads/test (with pdf)_1/risk_compilation_2018/JSON/50.json
# Processing page 51 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 51: Financial Risk Tolerance
# 38 | CFA Institute Research Foundation
# The application of scientific princi...
# Found 0 images on page 51
# No table extraction implemented yet for page 51
# Saved JSON for page 51: downloads/test (with pdf)_1/risk_compilation_2018/JSON/51.json
# Processing page 52 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 52: Financial Risk Tolerance
#  CFA Institute Research Foundation  |  39
# BASIC NOTIONS UNDERLYING
# CLASSI...
# Found 0 images on page 52
# No table extraction implemented yet for page 52
# Saved JSON for page 52: downloads/test (with pdf)_1/risk_compilation_2018/JSON/52.json
# Processing page 53 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 53: Financial Risk Tolerance
# 40 | CFA Institute Research Foundation
# VALIDITY
# Validity refers to the exte...
# Found 0 images on page 53
# No table extraction implemented yet for page 53
# Saved JSON for page 53: downloads/test (with pdf)_1/risk_compilation_2018/JSON/53.json
# Processing page 54 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 54: Financial Risk Tolerance
#  CFA Institute Research Foundation  |  41
# from an established scale that i...
# Found 0 images on page 54
# No table extraction implemented yet for page 54
# Saved JSON for page 54: downloads/test (with pdf)_1/risk_compilation_2018/JSON/54.json
# Processing page 55 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 55: Financial Risk Tolerance
# 42 | CFA Institute Research Foundation
# assessment, however, the size of the...
# Found 0 images on page 55
# No table extraction implemented yet for page 55
# Saved JSON for page 55: downloads/test (with pdf)_1/risk_compilation_2018/JSON/55.json
# Processing page 56 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 56: Financial Risk Tolerance
#  CFA Institute Research Foundation  |  43
# the probability that the individ...
# Found 0 images on page 56
# No table extraction implemented yet for page 56
# Saved JSON for page 56: downloads/test (with pdf)_1/risk_compilation_2018/JSON/56.json
# Processing page 57 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 57: Financial Risk Tolerance
# 44 | CFA Institute Research Foundation
# assessment instrument.1 Tests with h...
# Found 0 images on page 57
# No table extraction implemented yet for page 57
# Saved JSON for page 57: downloads/test (with pdf)_1/risk_compilation_2018/JSON/57.json
# Processing page 58 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 58: Financial Risk Tolerance
#  CFA Institute Research Foundation  |  45
# Consider the following questions...
# Found 0 images on page 58
# No table extraction implemented yet for page 58
# Saved JSON for page 58: downloads/test (with pdf)_1/risk_compilation_2018/JSON/58.json
# Processing page 59 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 59: Financial Risk Tolerance
# 46 | CFA Institute Research Foundation
# Which of these questions is an appro...
# Found 0 images on page 59
# No table extraction implemented yet for page 59
# Saved JSON for page 59: downloads/test (with pdf)_1/risk_compilation_2018/JSON/59.json
# Processing page 60 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 60: Financial Risk Tolerance
#  CFA Institute Research Foundation  |  47
# can be used to determine how man...
# Found 0 images on page 60
# No table extraction implemented yet for page 60
# Saved JSON for page 60: downloads/test (with pdf)_1/risk_compilation_2018/JSON/60.json
# Processing page 61 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 61: Financial Risk Tolerance
# 48 | CFA Institute Research Foundation
# or one with a lower reliability scor...
# Found 0 images on page 61
# No table extraction implemented yet for page 61
# Saved JSON for page 61: downloads/test (with pdf)_1/risk_compilation_2018/JSON/61.json
# Processing page 62 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 62: Financial Risk Tolerance
#  CFA Institute Research Foundation  |  49
# equivalence (tau equivalent) mod...
# Found 0 images on page 62
# No table extraction implemented yet for page 62
# Saved JSON for page 62: downloads/test (with pdf)_1/risk_compilation_2018/JSON/62.json
# Processing page 63 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 63: Financial Risk Tolerance
# 50 | CFA Institute Research Foundation
# and the intent matches her purposes)...
# Found 0 images on page 63
# No table extraction implemented yet for page 63
# Saved JSON for page 63: downloads/test (with pdf)_1/risk_compilation_2018/JSON/63.json
# Processing page 64 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 64: Financial Risk Tolerance
#  CFA Institute Research Foundation  |  51
# this procedure provides an estim...
# Found 0 images on page 64
# No table extraction implemented yet for page 64
# Saved JSON for page 64: downloads/test (with pdf)_1/risk_compilation_2018/JSON/64.json
# Processing page 65 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 65: Financial Risk Tolerance
# 52 | CFA Institute Research Foundation
# between a client’s risk profile, ris...
# Found 0 images on page 65
# No table extraction implemented yet for page 65
# Saved JSON for page 65: downloads/test (with pdf)_1/risk_compilation_2018/JSON/65.json
# Processing page 66 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 66: Financial Risk Tolerance
#  CFA Institute Research Foundation  |  53
# Bernstein, P.L. 1996. Against th...
# Found 0 images on page 66
# No table extraction implemented yet for page 66
# Saved JSON for page 66: downloads/test (with pdf)_1/risk_compilation_2018/JSON/66.json
# Processing page 67 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 67: Financial Risk Tolerance
# 54 | CFA Institute Research Foundation
# Saad, S., G.W. Carter, M. Rothenberg...
# Found 0 images on page 67
# No table extraction implemented yet for page 67
# Saved JSON for page 67: downloads/test (with pdf)_1/risk_compilation_2018/JSON/67.json
# Processing page 68 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 68:  CFA Institute Research Foundation  |  55
# RISK TOLERANCE
# AND CIRCUMSTANCES
# Elke U. Weber
# Joachim K...
# Found 0 images on page 68
# No table extraction implemented yet for page 68
# Saved JSON for page 68: downloads/test (with pdf)_1/risk_compilation_2018/JSON/68.json
# Processing page 69 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 69: Risk Tolerance and Circumstances
# 56  |  CFA Institute Research Foundation
# A TALE OF TWO FRAMEWORKS
# ...
# Found 0 images on page 69
# No table extraction implemented yet for page 69
# Saved JSON for page 69: downloads/test (with pdf)_1/risk_compilation_2018/JSON/69.json
# Processing page 70 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 70: Risk Tolerance and Circumstances
#  CFA Institute Research Foundation  |  57
# In addition to the atti...
# Found 0 images on page 70
# No table extraction implemented yet for page 70
# Saved JSON for page 70: downloads/test (with pdf)_1/risk_compilation_2018/JSON/70.json
# Processing page 71 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 71: Risk Tolerance and Circumstances
# 58  |  CFA Institute Research Foundation
# This example can be expan...
# Found 0 images on page 71
# No table extraction implemented yet for page 71
# Saved JSON for page 71: downloads/test (with pdf)_1/risk_compilation_2018/JSON/71.json
# Processing page 72 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 72: Risk Tolerance and Circumstances
#  CFA Institute Research Foundation  |  59
# vary from person to per...
# Found 0 images on page 72
# No table extraction implemented yet for page 72
# Saved JSON for page 72: downloads/test (with pdf)_1/risk_compilation_2018/JSON/72.json
# Processing page 73 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 73: Risk Tolerance and Circumstances
# 60  |  CFA Institute Research Foundation
# Figure 1 shows the study’...
# Found 0 images on page 73
# No table extraction implemented yet for page 73
# Saved JSON for page 73: downloads/test (with pdf)_1/risk_compilation_2018/JSON/73.json
# Processing page 74 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 74: Risk Tolerance and Circumstances
#  CFA Institute Research Foundation  |  61
# important driver of the...
# Found 0 images on page 74
# No table extraction implemented yet for page 74
# Saved JSON for page 74: downloads/test (with pdf)_1/risk_compilation_2018/JSON/74.json
# Processing page 75 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 75: Risk Tolerance and Circumstances
# 62  |  CFA Institute Research Foundation
# Weber, Blais, and Betz (2...
# Found 0 images on page 75
# No table extraction implemented yet for page 75
# Saved JSON for page 75: downloads/test (with pdf)_1/risk_compilation_2018/JSON/75.json
# Processing page 76 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 76: Risk Tolerance and Circumstances
#  CFA Institute Research Foundation  |  63
# When saving for retirem...
# Found 0 images on page 76
# No table extraction implemented yet for page 76
# Saved JSON for page 76: downloads/test (with pdf)_1/risk_compilation_2018/JSON/76.json
# Processing page 77 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 77: Risk Tolerance and Circumstances
# 64  |  CFA Institute Research Foundation
# savings. These three fact...
# Found 0 images on page 77
# No table extraction implemented yet for page 77
# Saved JSON for page 77: downloads/test (with pdf)_1/risk_compilation_2018/JSON/77.json
# Processing page 78 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 78: Risk Tolerance and Circumstances
#  CFA Institute Research Foundation  |  65
# time preferences and im...
# Found 0 images on page 78
# No table extraction implemented yet for page 78
# Saved JSON for page 78: downloads/test (with pdf)_1/risk_compilation_2018/JSON/78.json
# Processing page 79 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 79: Risk Tolerance and Circumstances
# 66  |  CFA Institute Research Foundation
# perceived risk of the fut...
# Found 0 images on page 79
# No table extraction implemented yet for page 79
# Saved JSON for page 79: downloads/test (with pdf)_1/risk_compilation_2018/JSON/79.json
# Processing page 80 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 80: Risk Tolerance and Circumstances
#  CFA Institute Research Foundation  |  67
# simple survey questions...
# Found 0 images on page 80
# No table extraction implemented yet for page 80
# Saved JSON for page 80: downloads/test (with pdf)_1/risk_compilation_2018/JSON/80.json
# Processing page 81 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 81: Risk Tolerance and Circumstances
# 68  |  CFA Institute Research Foundation
# 4.  HOLD HANDS
# Abraham L...
# Found 0 images on page 81
# No table extraction implemented yet for page 81
# Saved JSON for page 81: downloads/test (with pdf)_1/risk_compilation_2018/JSON/81.json
# Processing page 82 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 82: Risk Tolerance and Circumstances
#  CFA Institute Research Foundation  |  69
# modern portfolio theory...
# Found 0 images on page 82
# No table extraction implemented yet for page 82
# Saved JSON for page 82: downloads/test (with pdf)_1/risk_compilation_2018/JSON/82.json
# Processing page 83 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 83: Risk Tolerance and Circumstances
# 70  |  CFA Institute Research Foundation
# Jachimowicz, J.M., S. Cha...
# Found 0 images on page 83
# No table extraction implemented yet for page 83
# Saved JSON for page 83: downloads/test (with pdf)_1/risk_compilation_2018/JSON/83.json
# Processing page 84 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 84:  CFA Institute Research Foundation  |  71
# NEW VISTAS IN RISK PROFILING
# Greg B. Davies
# A CONFUSED LA...
# Found 0 images on page 84
# No table extraction implemented yet for page 84
# Saved JSON for page 84: downloads/test (with pdf)_1/risk_compilation_2018/JSON/84.json
# Processing page 85 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 85: New Vistas in Risk Profiling
# 72  |  CFA Institute Research Foundation
# of the world, in different org...
# Found 0 images on page 85
# No table extraction implemented yet for page 85
# Saved JSON for page 85: downloads/test (with pdf)_1/risk_compilation_2018/JSON/85.json
# Processing page 86 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 86: New Vistas in Risk Profiling
#  CFA Institute Research Foundation  |  73
# elements. The final part of ...
# Found 0 images on page 86
# No table extraction implemented yet for page 86
# Saved JSON for page 86: downloads/test (with pdf)_1/risk_compilation_2018/JSON/86.json
# Processing page 87 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 87: New Vistas in Risk Profiling
# 74  |  CFA Institute Research Foundation
# The latter, in contrast, frequ...
# Found 0 images on page 87
# No table extraction implemented yet for page 87
# Saved JSON for page 87: downloads/test (with pdf)_1/risk_compilation_2018/JSON/87.json
# Processing page 88 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 88: New Vistas in Risk Profiling
#  CFA Institute Research Foundation  |  75
# without jeopardising future ...
# Found 0 images on page 88
# No table extraction implemented yet for page 88
# Saved JSON for page 88: downloads/test (with pdf)_1/risk_compilation_2018/JSON/88.json
# Processing page 89 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 89: New Vistas in Risk Profiling
# 76  |  CFA Institute Research Foundation
# Interestingly, this observatio...
# Found 0 images on page 89
# No table extraction implemented yet for page 89
# Saved JSON for page 89: downloads/test (with pdf)_1/risk_compilation_2018/JSON/89.json
# Processing page 90 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 90: New Vistas in Risk Profiling
#  CFA Institute Research Foundation  |  77
# isolate each of these three ...
# Found 0 images on page 90
# No table extraction implemented yet for page 90
# Saved JSON for page 90: downloads/test (with pdf)_1/risk_compilation_2018/JSON/90.json
# Processing page 91 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 91: New Vistas in Risk Profiling
# 78  |  CFA Institute Research Foundation
# What is the right level of ris...
# Found 0 images on page 91
# No table extraction implemented yet for page 91
# Saved JSON for page 91: downloads/test (with pdf)_1/risk_compilation_2018/JSON/91.json
# Processing page 92 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 92: New Vistas in Risk Profiling
#  CFA Institute Research Foundation  |  79
# The answer is yes, very sign...
# Found 0 images on page 92
# No table extraction implemented yet for page 92
# Saved JSON for page 92: downloads/test (with pdf)_1/risk_compilation_2018/JSON/92.json
# Processing page 93 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 93: New Vistas in Risk Profiling
# 80  |  CFA Institute Research Foundation
# CASE 3: MULTIPLE FIXED GOALS
# N...
# Found 0 images on page 93
# No table extraction implemented yet for page 93
# Saved JSON for page 93: downloads/test (with pdf)_1/risk_compilation_2018/JSON/93.json
# Processing page 94 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 94: New Vistas in Risk Profiling
#  CFA Institute Research Foundation  |  81
# CASE 4: CONTINGENT GOALS
# Now...
# Found 0 images on page 94
# No table extraction implemented yet for page 94
# Saved JSON for page 94: downloads/test (with pdf)_1/risk_compilation_2018/JSON/94.json
# Processing page 95 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 95: New Vistas in Risk Profiling
# 82  |  CFA Institute Research Foundation
# adapt increases risk capacity....
# Found 0 images on page 95
# No table extraction implemented yet for page 95
# Saved JSON for page 95: downloads/test (with pdf)_1/risk_compilation_2018/JSON/95.json
# Processing page 96 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 96: New Vistas in Risk Profiling
#  CFA Institute Research Foundation  |  83
# But between these we have th...
# Found 0 images on page 96
# No table extraction implemented yet for page 96
# Saved JSON for page 96: downloads/test (with pdf)_1/risk_compilation_2018/JSON/96.json
# Processing page 97 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 97: New Vistas in Risk Profiling
# 84  |  CFA Institute Research Foundation
# Understanding these ephemeral ...
# Found 0 images on page 97
# No table extraction implemented yet for page 97
# Saved JSON for page 97: downloads/test (with pdf)_1/risk_compilation_2018/JSON/97.json
# Processing page 98 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 98: New Vistas in Risk Profiling
#  CFA Institute Research Foundation  |  85
# As Keynes is reputed to have...
# Found 0 images on page 98
# No table extraction implemented yet for page 98
# Saved JSON for page 98: downloads/test (with pdf)_1/risk_compilation_2018/JSON/98.json
# Processing page 99 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 99: New Vistas in Risk Profiling
# 86  |  CFA Institute Research Foundation
# assuaged by deliberately intro...
# Found 0 images on page 99
# No table extraction implemented yet for page 99
# Saved JSON for page 99: downloads/test (with pdf)_1/risk_compilation_2018/JSON/99.json
# Processing page 100 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 100: New Vistas in Risk Profiling
#  CFA Institute Research Foundation  |  87
# whereas the latter is more a...
# Found 0 images on page 100
# No table extraction implemented yet for page 100
# Saved JSON for page 100: downloads/test (with pdf)_1/risk_compilation_2018/JSON/100.json
# Processing page 101 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 101: New Vistas in Risk Profiling
# 88  |  CFA Institute Research Foundation
# 2.	 Confusion between risk tol...
# Found 0 images on page 101
# No table extraction implemented yet for page 101
# Saved JSON for page 101: downloads/test (with pdf)_1/risk_compilation_2018/JSON/101.json
# Processing page 102 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 102: New Vistas in Risk Profiling
#  CFA Institute Research Foundation  |  89
# That said, there are enticin...
# Found 0 images on page 102
# No table extraction implemented yet for page 102
# Saved JSON for page 102: downloads/test (with pdf)_1/risk_compilation_2018/JSON/102.json
# Processing page 103 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 103: New Vistas in Risk Profiling
# 90  |  CFA Institute Research Foundation
# With knowledge of the investor...
# Found 0 images on page 103
# No table extraction implemented yet for page 103
# Saved JSON for page 103: downloads/test (with pdf)_1/risk_compilation_2018/JSON/103.json
# Processing page 104 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 104: New Vistas in Risk Profiling
#  CFA Institute Research Foundation  |  91
# (particularly first time inv...
# Found 0 images on page 104
# No table extraction implemented yet for page 104
# Saved JSON for page 104: downloads/test (with pdf)_1/risk_compilation_2018/JSON/104.json
# Processing page 105 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 105: New Vistas in Risk Profiling
# 92  |  CFA Institute Research Foundation
# REFERENCES
# Benartzi, S., and R...
# Found 0 images on page 105
# No table extraction implemented yet for page 105
# Saved JSON for page 105: downloads/test (with pdf)_1/risk_compilation_2018/JSON/105.json
# Processing page 106 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 106: New Vistas in Risk Profiling
#  CFA Institute Research Foundation  |  93
# Slovic, P. 1995. “The Constr...
# Found 0 images on page 106
# No table extraction implemented yet for page 106
# Saved JSON for page 106: downloads/test (with pdf)_1/risk_compilation_2018/JSON/106.json
# Processing page 107 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 107: ...
# Found 0 images on page 107
# No table extraction implemented yet for page 107
# Saved JSON for page 107: downloads/test (with pdf)_1/risk_compilation_2018/JSON/107.json
# Processing page 108 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 108: CFA Institute
# Research Foundation
# Board of Trustees
# 2017–2018
# Officers and Directors
# Executive Di...
# Found 0 images on page 108
# No table extraction implemented yet for page 108
# Saved JSON for page 108: downloads/test (with pdf)_1/risk_compilation_2018/JSON/108.json
# Processing page 109 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 109: Ameritech
# Anonymous
# Robert D. Arnott
# Theodore R. Aronson, CFA
# Asahi Mutual Life Insurance Company
# Ba...
# Found 0 images on page 109
# No table extraction implemented yet for page 109
# Saved JSON for page 109: downloads/test (with pdf)_1/risk_compilation_2018/JSON/109.json
# Processing page 110 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 110: ...
# Found 0 images on page 110
# No table extraction implemented yet for page 110
# Saved JSON for page 110: downloads/test (with pdf)_1/risk_compilation_2018/JSON/110.json
# Processing page 111 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 111: ...
# Found 0 images on page 111
# No table extraction implemented yet for page 111
# Saved JSON for page 111: downloads/test (with pdf)_1/risk_compilation_2018/JSON/111.json
# Processing page 112 of downloads/test (with pdf)_1/risk_compilation_2018.pdf
# Extracted text for page 112: Available online at www.cfapubs.org
# 9 781944 960469
# ISBN 978-1-944960-46-9
# ...
# Found 0 images on page 112
# No table extraction implemented yet for page 112
# Saved JSON for page 112: downloads/test (with pdf)_1/risk_compilation_2018/JSON/112.json
# Checking directory: downloads/Mail with image_1
# Found PDF: downloads/Mail with image_1/Final Project Proposaledited.pdf
# Opening PDF: downloads/Mail with image_1/Final Project Proposaledited.pdf
# Creating directories for extracted content:
#   JSON directory: downloads/Mail with image_1/Final Project Proposaledited/JSON
#   Image directory: downloads/Mail with image_1/Final Project Proposaledited/Image
#   CSV directory: downloads/Mail with image_1/Final Project Proposaledited/CSV
# Processing page 1 of downloads/Mail with image_1/Final Project Proposaledited.pdf
# Extracted text for page 1: Final Project Proposal
# Due: 22nd Nov 24 03:59 pm EST
# Submission:
#
# 1. Github Repo Link
# Additiona...
# Found 0 images on page 1
# No table extraction implemented yet for page 1
# Saved JSON for page 1: downloads/Mail with image_1/Final Project Proposaledited/JSON/1.json
# Processing page 2 of downloads/Mail with image_1/Final Project Proposaledited.pdf
# Extracted text for page 2: Data Sources: Identify and describe the sources of data to be collected, processed, and analyzed. or...
# Found 0 images on page 2
# No table extraction implemented yet for page 2
# Saved JSON for page 2: downloads/Mail with image_1/Final Project Proposaledited/JSON/2.json
# Processing page 3 of downloads/Mail with image_1/Final Project Proposaledited.pdf
# Extracted text for page 3: Deploy the application on a cloud platform such as AWS, Google Cloud, or Azure, making it publicly a...
# Found 0 images on page 3
# No table extraction implemented yet for page 3
# Saved JSON for page 3: downloads/Mail with image_1/Final Project Proposaledited/JSON/3.json
# Checking directory: downloads/Test Email_5
# Checking directory: downloads/Test Email_2
# Checking directory: downloads/Test Email_3
# Checking directory: downloads/Test Email_4
# Checking directory: downloads/Test Mail from Different Domain Mail_1
# Checking directory: downloads/Test Email_1
# Checking directory: downloads/Test Email_6
